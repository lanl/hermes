# %%
from pyhermes import empir
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# set the working dir and the file dir
working_dir = "/path/to/working/directory"
file_dir = "some_file_name"

# set the path to the data
data_path = working_dir + "/" + file_dir + "/"
